# %% [markdown]
# ### Importing Necessary Libraries

# %%
import re
import os
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt 

from sklearn.linear_model import(
    LinearRegression,
    ElasticNet,
    Lasso,
    Ridge
)

from sklearn.tree import(
    DecisionTreeClassifier,
    DecisionTreeRegressor
)

from sklearn.ensemble import(
    RandomForestClassifier,
    RandomForestRegressor
)

from sklearn.metrics import(
    accuracy_score,
    roc_curve,
    root_mean_squared_error,
    mean_absolute_error,
    mean_squared_error,
    f1_score,
    classification_report,
    confusion_matrix,
    r2_score
)

from sklearn.preprocessing import(
    StandardScaler,
    MinMaxScaler,
    OneHotEncoder,
    LabelEncoder,
    LabelBinarizer
)

import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Dell\\Documents\\GEN_AI\\Data_Science\\Pandas\\Data_Analysis\\used_car_price_prediction'

# %%
os.makedirs('ML_MODEL',exist_ok=True)

# %%
path=os.path.join('Data_Sets','used_cars.csv')
path
# Out:
# 'Data_Sets\\used_cars.csv'

# %%
df=pd.read_csv(path)

# %% [markdown]
# ### Basic Inspection in Data

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',None)
df.head(2)
# Out:
#      brand                            model  model_year      milage  \
# 0     Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1  Hyundai                     Palisade SEL        2021  34,742 mi.
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
#
#         transmission          ext_col int_col  \
# 0        6-Speed A/T            Black   Black
# 1  8-Speed Automatic  Moonlight Cloud    Gray
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005

# %%
df['brand'].value_counts()
# Out:
# brand
# Ford             386
# BMW              375
# Mercedes-Benz    315
# Chevrolet        292
# Porsche          201
# Audi             200
# Toyota           199
# Lexus            163
# Jeep             143
# Land             130
# Nissan           116
# Cadillac         107
# GMC               91
# RAM               91
# Dodge             90
# Tesla             87
# Kia               76
# Hyundai           72
# Subaru            64
# Acura             64
# Mazda             64
# Honda             63
# INFINITI          59
# Volkswagen        59
# Lincoln           52
# Jaguar            47
# Volvo             38
# Maserati          34
# Bentley           33
# MINI              33
# Buick             30
# Chrysler          28
# Lamborghini       26
# Genesis           20
# Mitsubishi        20
# Alfa              19
# Rivian            17
# Hummer            16
# Pontiac           15
# Ferrari           12
# Rolls-Royce       11
# Aston              9
# Scion              6
# McLaren            6
# Saturn             5
# FIAT               5
# Lotus              4
# Lucid              3
# Mercury            3
# Karma              2
# Saab               2
# Bugatti            1
# Polestar           1
# Plymouth           1
# smart              1
# Maybach            1
# Suzuki             1
# Name: count, dtype: int64

# %%
list(df.columns)
# Out:
# ['brand',
#  'model',
#  'model_year',
#  'milage',
#  'fuel_type',
#  'engine',
#  'transmission',
#  'ext_col',
#  'int_col',
#  'accident',
#  'clean_title',
#  'price']

# %%
df.shape
# Out:
# (4009, 12)

# %%
df.describe()
# Out:
#         model_year
# count  4009.000000
# mean   2015.515590
# std       6.104816
# min    1974.000000
# 25%    2012.000000
# 50%    2017.000000
# 75%    2020.000000
# max    2024.000000

# %%
df.describe(include='all')
# Out:
#        brand    model   model_year       milage fuel_type  \
# count   4009     4009  4009.000000         4009      3839
# unique    57     1898          NaN         2818         7
# top     Ford  M3 Base          NaN  110,000 mi.  Gasoline
# freq     386       30          NaN           16      3309
# mean     NaN      NaN  2015.515590          NaN       NaN
# std      NaN      NaN     6.104816          NaN       NaN
# min      NaN      NaN  1974.000000          NaN       NaN
# 25%      NaN      NaN  2012.000000          NaN       NaN
# 50%      NaN      NaN  2017.000000          NaN       NaN
# 75%      NaN      NaN  2020.000000          NaN       NaN
# max      NaN      NaN  2024.000000          NaN       NaN
#
#                             engine transmission ext_col int_col  \
# count                         4009         4009    4009    4009
# unique                        1146           62     319     156
# top     2.0L I4 16V GDI DOHC Turbo          A/T   Black   Black
# freq                            52         1037     905    2025
# mean                           NaN          NaN     NaN     NaN
# std                            NaN          NaN     NaN     NaN
# min                            NaN          NaN     NaN     NaN
# 25%                            NaN          NaN     NaN     NaN
# 50%                            NaN          NaN     NaN     NaN
# 75%                            NaN          NaN     NaN     NaN
# max                            NaN          NaN     NaN     NaN
#
#              accident clean_title    price
# count            3896        3413     4009
# unique              2           1     1569
# top     None reported         Yes  $15,000
# freq             2910        3413       39
# mean              NaN         NaN      NaN
# std               NaN         NaN      NaN
# min               NaN         NaN      NaN
# 25%               NaN         NaN      NaN
# 50%               NaN         NaN      NaN
# 75%               NaN         NaN      NaN
# max               NaN         NaN      NaN

# %%
df.dtypes
# Out:
# brand           object
# model           object
# model_year       int64
# milage          object
# fuel_type       object
# engine          object
# transmission    object
# ext_col         object
# int_col         object
# accident        object
# clean_title     object
# price           object
# dtype: object

# %%
df.head(1)
# Out:
#   brand                            model  model_year      milage  \
# 0  Ford  Utility Police Interceptor Base        2013  51,000 mi.
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
#
#   transmission ext_col int_col                                accident  \
# 0  6-Speed A/T   Black   Black  At least 1 accident or damage reported
#
#   clean_title    price
# 0         Yes  $10,300

# %%
df['milage']=df['milage'].str.replace('mi.','').str.replace(',','').astype(float)
df['milage'].head()
# Out:
# 0    51000.0
# 1    34742.0
# 2    22372.0
# 3    88900.0
# 4     9835.0
# Name: milage, dtype: float64

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999

# %%
df['price']=df['price'].str.replace('$','').str.replace(',','').astype(float)
df['price'].dtype
# Out:
# dtype('float64')

# %%
df.head(5)
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  10300.0
# 1  At least 1 accident or damage reported         Yes  38005.0
# 2                           None reported         NaN  54598.0
# 3                           None reported         Yes  15500.0
# 4                           None reported         NaN  34999.0

# %%
df['Engine_Capacity']=df['engine'].str.extract(r'(\d+\.\d+L|\d+L|\d+\.\d+\s*Liter|\d\s*L|\d\s*Liter)')

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price Engine_Capacity
# 0  At least 1 accident or damage reported         Yes  10300.0            3.7L
# 1  At least 1 accident or damage reported         Yes  38005.0            3.8L
# 2                           None reported         NaN  54598.0       3.5 Liter
# 3                           None reported         Yes  15500.0            3.5L
# 4                           None reported         NaN  34999.0            2.0L

# %%
df['Engine_Capacity']=df['Engine_Capacity'].str.replace('Liter','').str.replace('L','').astype(float)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price  \
# 0  At least 1 accident or damage reported         Yes  10300.0
# 1  At least 1 accident or damage reported         Yes  38005.0
# 2                           None reported         NaN  54598.0
# 3                           None reported         Yes  15500.0
# 4                           None reported         NaN  34999.0
#
#    Engine_Capacity
# 0              3.7
# 1              3.8
# 2              3.5
# 3              3.5
# 4              2.0

# %%
df['Horse_Power']=df['engine'].str.extract(r'(\d+\.\d+HP|\d+HP)')

# %%
df['Horse_Power']=df['Horse_Power'].str.replace('HP','').astype(float)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price  \
# 0  At least 1 accident or damage reported         Yes  10300.0
# 1  At least 1 accident or damage reported         Yes  38005.0
# 2                           None reported         NaN  54598.0
# 3                           None reported         Yes  15500.0
# 4                           None reported         NaN  34999.0
#
#    Engine_Capacity  Horse_Power
# 0              3.7        300.0
# 1              3.8          NaN
# 2              3.5          NaN
# 3              3.5        354.0
# 4              2.0          NaN

# %%
df.drop(columns=['engine'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type       transmission                 ext_col int_col  \
# 0  E85 Flex Fuel        6-Speed A/T                   Black   Black
# 1       Gasoline  8-Speed Automatic         Moonlight Cloud    Gray
# 2       Gasoline          Automatic                    Blue   Black
# 3         Hybrid        7-Speed A/T                   Black   Black
# 4       Gasoline  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price  \
# 0  At least 1 accident or damage reported         Yes  10300.0
# 1  At least 1 accident or damage reported         Yes  38005.0
# 2                           None reported         NaN  54598.0
# 3                           None reported         Yes  15500.0
# 4                           None reported         NaN  34999.0
#
#    Engine_Capacity  Horse_Power
# 0              3.7        300.0
# 1              3.8          NaN
# 2              3.5          NaN
# 3              3.5        354.0
# 4              2.0          NaN

# %%
df['Accident_Status']=df['accident'].apply(lambda x:"NO" if x=="None reported" else "YES")

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type       transmission                 ext_col int_col  \
# 0  E85 Flex Fuel        6-Speed A/T                   Black   Black
# 1       Gasoline  8-Speed Automatic         Moonlight Cloud    Gray
# 2       Gasoline          Automatic                    Blue   Black
# 3         Hybrid        7-Speed A/T                   Black   Black
# 4       Gasoline  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price  \
# 0  At least 1 accident or damage reported         Yes  10300.0
# 1  At least 1 accident or damage reported         Yes  38005.0
# 2                           None reported         NaN  54598.0
# 3                           None reported         Yes  15500.0
# 4                           None reported         NaN  34999.0
#
#    Engine_Capacity  Horse_Power Accident_Status
# 0              3.7        300.0             YES
# 1              3.8          NaN             YES
# 2              3.5          NaN              NO
# 3              3.5        354.0              NO
# 4              2.0          NaN              NO

# %%
df.drop('accident',axis=1,inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type       transmission                 ext_col int_col  \
# 0  E85 Flex Fuel        6-Speed A/T                   Black   Black
# 1       Gasoline  8-Speed Automatic         Moonlight Cloud    Gray
# 2       Gasoline          Automatic                    Blue   Black
# 3         Hybrid        7-Speed A/T                   Black   Black
# 4       Gasoline  8-Speed Automatic  Glacier White Metallic   Black
#
#   clean_title    price  Engine_Capacity  Horse_Power Accident_Status
# 0         Yes  10300.0              3.7        300.0             YES
# 1         Yes  38005.0              3.8          NaN             YES
# 2         NaN  54598.0              3.5          NaN              NO
# 3         Yes  15500.0              3.5        354.0              NO
# 4         NaN  34999.0              2.0          NaN              NO

# %%
df['Power_Density']=df['Horse_Power']/df['Engine_Capacity']
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type       transmission                 ext_col int_col  \
# 0  E85 Flex Fuel        6-Speed A/T                   Black   Black
# 1       Gasoline  8-Speed Automatic         Moonlight Cloud    Gray
# 2       Gasoline          Automatic                    Blue   Black
# 3         Hybrid        7-Speed A/T                   Black   Black
# 4       Gasoline  8-Speed Automatic  Glacier White Metallic   Black
#
#   clean_title    price  Engine_Capacity  Horse_Power Accident_Status  \
# 0         Yes  10300.0              3.7        300.0             YES
# 1         Yes  38005.0              3.8          NaN             YES
# 2         NaN  54598.0              3.5          NaN              NO
# 3         Yes  15500.0              3.5        354.0              NO
# 4         NaN  34999.0              2.0          NaN              NO
#
#    Power_Density
# 0      81.081081
# 1            NaN
# 2            NaN
# 3     101.142857
# 4            NaN

# %%
df.isnull().sum()
# Out:
# brand                0
# model                0
# model_year           0
# milage               0
# fuel_type          170
# transmission         0
# ext_col              0
# int_col              0
# clean_title        596
# price                0
# Engine_Capacity    217
# Horse_Power        808
# Accident_Status      0
# Power_Density      940
# dtype: int64

# %%
missing_info={}
for col in df.columns:
    if df[col].isnull().sum()>0:
        missing_count=(df[col].isnull().sum()/len(df)*100)
        missing_info[col]=round(missing_count,2)

print('The missing values in percentage')
for col,perc in missing_info.items():
    print(f'{col}:{perc}%')
# Out:
# The missing values in percentage
# fuel_type:4.24%
# clean_title:14.87%
# Engine_Capacity:5.41%
# Horse_Power:20.15%
# Power_Density:23.45%

# %%
numerical_columns=df.select_dtypes(include=['number','float32','float64','int32','int64']).columns
df[numerical_columns].head()
# Out:
#    model_year   milage    price  Engine_Capacity  Horse_Power  Power_Density
# 0        2013  51000.0  10300.0              3.7        300.0      81.081081
# 1        2021  34742.0  38005.0              3.8          NaN            NaN
# 2        2022  22372.0  54598.0              3.5          NaN            NaN
# 3        2015  88900.0  15500.0              3.5        354.0     101.142857
# 4        2021   9835.0  34999.0              2.0          NaN            NaN

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df)
plt.title('Box plots for Numerical columns')
plt.tight_layout(pad=0.2)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df['model_year'])
plt.title('Box plots for Numerical columns')
plt.tight_layout(pad=0.2)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df['milage'])
plt.title('Box plots for Numerical columns')
plt.tight_layout(pad=0.2)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df['price'])
plt.title('Box plots for Numerical columns')
plt.tight_layout(pad=0.2)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df['Engine_Capacity'])
plt.title('Box plots for Numerical columns')
plt.tight_layout(pad=0.2)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df['Horse_Power'])
plt.title('Box plots for Numerical columns')
plt.tight_layout(pad=0.2)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df['Power_Density'])
plt.title('Box plots for Numerical columns')
plt.tight_layout(pad=0.2)
plt.show()

# %%
x=np.array([2,4,6,10])
y1=np.exp(x)+np.sin(x)
y2=np.sin(x**2)+np.exp(x)+np.log(x)
y3=np.atan(x)
y4=np.pi*x**3+np.cosh(x)
y5=np.sin(x)+np.cos(x)
y6=np.atan(x)+np.sinh(x)
y1,y2,y3,y4,y5,y6
# Out:
# (array([8.29835353e+00, 5.38413475e+01, 4.03149378e+02, 2.20259218e+04]),
#  array([7.32540078e+00, 5.56965411e+01, 4.04228774e+02, 2.20282620e+04]),
#  array([1.10714872, 1.32581766, 1.40564765, 1.47112767]),
#  array([   28.89493692,   228.37016267,   880.2996493 , 14154.82557369]),
#  array([ 0.49315059, -1.41044612,  0.68075479, -1.38309264]),
#  array([4.73400913e+00, 2.86157349e+01, 2.03118805e+02, 1.10147040e+04]))

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,3,1)
plt.plot(x,y1,linestyle='--',linewidth=1.5,color='red')
plt.title('First Figure')
plt.xlabel('X_Value')
plt.ylabel('Y_Value')
plt.xticks(rotation=180)
plt.yticks(rotation=45)

plt.subplot(2,3,2)
plt.plot(x,y1,linestyle=':',linewidth=1.5,color='green')
plt.title('Second Figure')
plt.xlabel('X_Value')
plt.ylabel('Y_Value')

plt.subplot(2,3,3)
plt.plot(x,y1,linestyle='--',linewidth=1.5,color='yellow')
plt.title('Third Figure')
plt.xlabel('X_Value')
plt.ylabel('Y_Value')

plt.subplot(2,3,4)
plt.plot(x,y1,linestyle='--',linewidth=1.5,color='orange')
plt.title('Fourth Figure')
plt.xlabel('X_Value')
plt.ylabel('Y_Value')

plt.subplot(2,3,5)
plt.plot(x,y1,linestyle='--',linewidth=1.5,color='blue')
plt.title('Fifth Figure')
plt.xlabel('X_Value')
plt.ylabel('Y_Value')

plt.subplot(2,3,6)
plt.plot(x,y1,linestyle='--',linewidth=1.5,color='purple')
plt.title('Sixth Figure')
plt.xlabel('X_Value')
plt.ylabel('Y_Value')

plt.tight_layout(pad=2)
plt.savefig('Basic_Line_Plot.png',dpi=1000)

plt.show()

# %% [markdown]
# ### Basic Scatter Plot

# %%
x=[10,20,30,40,50,60,70,80,90]
a=[8,1,7,2,0,3,7,3,2]

# %%
plt.scatter(x,a)
plt.show()

# %% [markdown]
# ### Markers in the Scatter Plot

# %%
plt.scatter(x,a,marker="*",c="orange",s=50)
plt.show()

# %% [markdown]
# ### Adding two Markers in same plot

# %%
z=[10,20,30,40,50,60,70,80,90]
x=[8,1,7,2,0,3,7,3,2]
y=[4,2,5,6,9,1,4,5,3]

# %%
plt.scatter(z,x,marker="*",c="g",s=100)
plt.scatter(z,y,marker=".",c="r",s=200)
plt.show()

# %% [markdown]
# ### Adding two subplots

# %%
plt.subplot(1,2,1)
plt.plot(z,x,color='red')
plt.scatter(z,x,marker="*",c="g",s=100)

plt.subplot(1,2,2)
plt.plot(z,y,color='purple')
plt.scatter(z,y,marker=".",c="r",s=200)

# %%
# pie chart

# %%
fruits={
    'Apple':20,
    'Papaya':10,
    'Mango':25,
    'Banana':15,
    'Tomato':20,
    'Strawberry':30,
    'Watermelon':2,
    'Kiwi':8,
    'DragonFruits':4,
    'Cherry':20
}

# %%
keys=list(fruits.keys())
keys
# Out:
# ['Apple',
#  'Papaya',
#  'Mango',
#  'Banana',
#  'Tomato',
#  'Strawberry',
#  'Watermelon',
#  'Kiwi',
#  'DragonFruits',
#  'Cherry']

# %%
values=list(fruits.values())
values
# Out:
# [20, 10, 25, 15, 20, 30, 2, 8, 4, 20]

# %%
color=['red','yellow','blue','orange','purple','pink','green','cyan','white','black']

# %%
plt.figure(figsize=(20,15))

plt.pie(values,labels=keys,colors=color,autopct='%0.02f%%',startangle=90)
plt.title('This is piecharts for fruits data')

plt.legend(loc='upper right',bbox_to_anchor=(1.5,1))
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ### Making Histogram

# %%
iris_df=pd.read_csv('Data_Sets//IRIS.csv')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
plt.Figure(figsize=(20,15))
plt.subplot(1,4,1)
plt.hist(iris_df['sepal_length'],bins=30,color="g")

plt.subplot(1,4,2)
plt.hist(iris_df['petal_length'],bins=30,color="r")

plt.subplot(1,4,3)
plt.hist(iris_df['sepal_width'],bins=30,color="b")

plt.subplot(1,4,4)
plt.hist(iris_df['petal_width'],bins=30,color="y")
plt.tight_layout(pad=2)
plt.show()
